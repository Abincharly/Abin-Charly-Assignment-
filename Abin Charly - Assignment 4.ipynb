# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Load the dataset into python environment

# %%
df = pd.read_csv("C:/Users/abinc/Downloads/titanic_dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 2. Make ‘PassengerId’ as the index column

# %%
df.set_index("PassengerId", inplace=True)
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# 3. Check the basic details of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# 4. Fill in all the missing values present in all the columns in the dataset

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
## Filling the categorical columns with mode

# %%
df['Cabin'] = df['Cabin'].fillna(df['Cabin'].mode()[0])

# %%
df['Cabin'].isna().sum()
# Out:
# 0

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df['Embarked'].isna().sum()
# Out:
# 0

# %%
## Filling the categorical columns with median

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df['Age'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %% [markdown]
# 5. Check and handle outliers in at least 3 columns in the dataset

# %%
plt.boxplot(df['Survived'])
plt.title('Boxplot for Survived')
# Out:
# Text(0.5, 1.0, 'Boxplot for Survived')

# %%
plt.boxplot(df['Pclass'])
plt.title('Boxplot for Pclass')
# Out:
# Text(0.5, 1.0, 'Boxplot for Pclass')

# %%
plt.boxplot(df['Age'])
plt.title('Boxplot for Age')
# Out:
# Text(0.5, 1.0, 'Boxplot for Age')

# %%
Q1 = np.percentile(df['Age'],25)
Q1
# Out:
# 22.0

# %%
Q2 = np.percentile(df['Age'],50)
Q2
# Out:
# 28.0

# %%
Q3 = np.percentile(df['Age'],75)
Q3
# Out:
# 35.0

# %%
IQR = Q3 - Q1
IQR
# Out:
# 13.0

# %%
low_limit = Q1-1.5*IQR
upr_lim = Q3+1.5*IQR

# %%
low_limit
# Out:
# 2.5

# %%
upr_lim
# Out:
# 54.5

# %%
outliers=[]
for i in df['Age']:
    if(i>upr_lim) or (i<low_limit):
        outliers.append(i)

# %%
outliers
# Out:
# [2.0,
#  58.0,
#  55.0,
#  2.0,
#  66.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  2.0,
#  55.5,
#  1.0,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  60.0,
#  1.0,
#  1.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  2.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  2.0,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %%
ind=df['Age']>upr_lim
df.loc[ind].index
# Out:
# Int64Index([ 12,  16,  34,  55,  95,  97, 117, 153, 171, 175, 196, 233, 253,
#             269, 276, 281, 327, 367, 439, 457, 468, 484, 488, 493, 494, 546,
#             556, 571, 588, 626, 627, 631, 648, 660, 673, 685, 695, 746, 773,
#             830, 852, 880],
#            dtype='int64', name='PassengerId')

# %%
df.drop([ 12,  16,  34,  55,  95,  97, 117, 153, 171, 175, 196, 233, 253,
            269, 276, 281, 327, 367, 439, 457, 468, 484, 488, 493, 494, 546,
            556, 571, 588, 626, 627, 631, 648, 660, 673, 685, 695, 746, 773,
            830, 852, 880])
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# 6. Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
df1=df.drop(["Name","Sex","Ticket","Embarked"],axis=1)

# %%
df1.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare    Cabin
# PassengerId
# 1                   0       3  22.0      1      0   7.2500  B96 B98
# 2                   1       1  38.0      1      0  71.2833      C85
# 3                   1       3  26.0      0      0   7.9250  B96 B98
# 4                   1       1  35.0      1      0  53.1000     C123
# 5                   0       3  35.0      0      0   8.0500  B96 B98

# %%
X = df1.drop('Survived',axis=1) ## Feature set
y = df1['Survived']     ## Target set

# %%
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0,1))

# %%
X = min_max_scaler.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10404/1999442134.py in <module>
# ----> 1 X = min_max_scaler.fit_transform(X)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     361         # Reset internal state before fitting
#     362         self._reset()
# --> 363         return self.partial_fit(X, y)
#     364
#     365     def partial_fit(self, X, y=None):
#
# ...

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X=pd.DataFrame(X)

# %%
X.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.361582    0.523008    0.381594   32.204208
# std      0.836071   13.019697    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   35.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %%
X1=df.drop(["Survived","Pclass","Age","SibSp","Parch","Fare"],axis=1)

# %%
X1.head()
# Out:
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
#
#                        Ticket    Cabin Embarked
# PassengerId
# 1                   A/5 21171  B96 B98        S
# 2                    PC 17599      C85        C
# 3            STON/O2. 3101282  B96 B98        S
# 4                      113803     C123        S
# 5                      373450  B96 B98        S

# %%
X=pd.concat([df,X1],axis=1)

# %%
X.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare    Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500  B96 B98        S
# 2                1      0          PC 17599  71.2833      C85        C
# ...
